# %% [markdown]
# <a href="https://colab.research.google.com/github/surabhi-priyadarshini/Hotel-bookings-analysis/blob/main/Hotel_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name - Hotel Booking Analysis**

# %% [markdown]
# **Project** **Type** - **EDA**
#
# **Contribution** - **Individual**
#
# **Project** **By** - **Surabhi** **Priyadarshini**

# %% [markdown]
# ### **Project Summary -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions! This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data..

# %% [markdown]
# Define Your Business Objective?

# %% [markdown]
# The project aims to gain interesting insight into customers’ behavior when booking a hotel. The demand for different segment of customer may differ and forecasting become harder as it may requires different model for different segment.These insights can guide hotels to adjust their customer strategies and make preparation for unknown.

# %% [markdown]
# ### **Attribute Information**

# %% [markdown]
# Hotel: H1=Resort Hotel
#        H2=City Hotel
#
# is_cancelled: If the booking was cancelled(1) or not(0)
#
# lead_time: Number of days that elapsed between the entering date of the booking into the PMS & arrival date.
#
# arrival_date_year: Year of arrival date
#
# arrival_date_month: Month of arrival date
#
# arrival_date_week_number: Week number for arrival date
#
# arrival_dat_day: Day of arrival date
#
# stays_in_weekend_nights: Number of weekend nights(Saturday or Sunday)the guest stayed or booked to stay at the hotel
#
# stays_in_week_nights: Number of week nights(Monday to Friday)the guest stayed or booked to stay at the hotel
#
# adults: Number of adults
#
# children: Number of children
#
# babies: Number of babies
#
# meal: Kind of meal opted for
#
# country: Country code
#
# market_segment: Which segment the customer belongs to

# %% [markdown]
# # **1. Know Your Data**

# %% [markdown]
# # **Import Libraries**

# %%
# Importing necessary libraries needed in EDA
import numpy as np
import pandas as pd
# for visualisation
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Dataset Loading**

# %%
df = pd.read_csv('/content/drive/MyDrive/hotel booking.csv')

# %%
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# **Dataset First View**

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.duplicated().sum()
# Out:
# 31994

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#Dropping duplicate values
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (87396, 32)

# %%
df1 = df.copy()

# %%
df1.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df1['children' ].fillna(0, inplace = True)
df1['company' ].fillna(0, inplace = True)
df1['agent' ].fillna(0, inplace = True)

# replacing null values in country column as 'NA'

df1['country'].fillna('NA', inplace = True)

# %%
df1.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
df1
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### **Bookings are more on weekdays or weekends?**

# %%
# Calculating the total stays for weekend nights and week nights
total_weekend_nights = df1['stays_in_weekend_nights'].sum()
total_week_nights = df1['stays_in_week_nights'].sum()


# Comparing the totals

if total_week_nights > total_weekend_nights:
  print(f'Week days stays are higher: {total_week_nights}')
else:
  print(f'Weekend stays are higher: {total_weekend_nights}')

# Data for plotting
x = ['Weekend Nights', 'Week Nights']
y = [total_weekend_nights, total_week_nights]

# Creating the bar chart
plt.figure(figsize=(8, 6))
bar=plt.bar(x, y, color=['blue', 'green'])

for bar in bar:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 5000, int(yval), ha='center', va='bottom')

plt.xlabel('Type of Stay')
plt.ylabel('Total Stays')
plt.title('Comparison of Total Stays on Weekends vs. Weekdays')
plt.show()
# Out:
# Week days stays are higher: 229449

# %% [markdown]
# CONCLUSION: The bookings are more on week days thaan weekends.

# %% [markdown]
# ### **ADR by month**

# %%
# Converting the 'arrival_date_month' column to a categorical type with proper order
months_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df1['arrival_date_month'] = pd.Categorical(df1['arrival_date_month'], categories=months_order, ordered=True)


# Group by 'arrival_date_month' and calculating the average ADR
monthly_adr = df1.groupby('arrival_date_month')['adr'].mean().reset_index()


plt.figure(figsize=(10, 6))
plt.plot(monthly_adr['arrival_date_month'], monthly_adr['adr'], marker='o', linestyle='-')
plt.xticks(monthly_adr['arrival_date_month'], months_order, rotation=45)
plt.xlabel('Month')
plt.ylabel('Average Daily Rate (ADR)')
plt.title('Average Daily Rate (ADR) by Month')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# CONCLUSION:
#
# ▶ **Seasonal trends**:
#
# ▪ The "**August**" month has the highest ADR. This is peak tourist month with special events that drive up demands.
#
# ▪The "**January**" month has lowest ADR. This is off-peak tourist month with lower demand.
#
# ▶**Price fluctuations**: The ADR gradually increases from January to August and then sharply declines from August to November, with a slight uptick in December.

# %% [markdown]
# **Count & proportion of bookings**

# %%
hotel_counts=df1.groupby( 'hotel').size().reset_index(name='num_bookings')

total_bookings = hotel_counts['num_bookings'].sum()
hotel_counts['Proportion'] = hotel_counts['num_bookings'] / total_bookings

print(hotel_counts)

plt.figure(figsize=(8, 8))

plt.pie(hotel_counts['Proportion'], labels=hotel_counts['hotel'], autopct='%1.1f%%',explode=(0.00,0.09), colors=['skyblue', 'lightgreen'])
plt.title('Proportion of Bookings Over Hotel Type')
plt.show()
# Out:
#           hotel  num_bookings  Proportion
# 0    City Hotel         53428    0.611332
# 1  Resort Hotel         33968    0.388668

# %% [markdown]
# CONCLUSION: City Hotel is more popular among the customers as they've highest number of bookings.

# %% [markdown]
# ### **Number of booking across months**

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['arrival_date_month'],hue=df['hotel'])
plt.title("Number of booking across months", fontsize = 25)
plt.show()

# %% [markdown]
# **CONCLUSION**:
#
# **Booking Trends by Month**:
#
# **July and August**: These months have the highest number of bookings for both Resort Hotels and City Hotels, with City Hotels having slightly more bookings.
#
# **November and December**: These months show the lowest number of bookings, indicating a general off-peak season.
#
# **March to June**: There is a steady increase in bookings, with City Hotels consistently having more bookings than Resort Hotels.
#
# **Comparison Between Hotel Types**:
#
# **City Hotels** generally have more bookings than Resort Hotels throughout the year.
#
# **Insights**:
#
# **Peak Seasons** :
#  Both hotel types experience peak bookings during the summer months (July and August), suggesting high demand possibly due to summer vacations.
#
# **Off-Peak Seasons**: The winter months, especially November and December, see a significant drop in bookings for both hotel types.

# %% [markdown]
# 2. **Distribution of ADR (Average Daily Rate) by Hotel Type**

# %%
bookings_months=df.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()

plt.figure(figsize=(15,5))

# Plotting the values in a line chart
sns.lineplot(x=bookings_months['arrival_date_month'],y=bookings_months['adr'],hue=bookings_months['hotel'])

# Setting the labels and title
plt.title('ADR across each month', fontsize=20)
plt.xlabel('Month Name', fontsize=12)
plt.ylabel('ADR', fontsize=12)

# Show chart
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Summary Statistics**

# %%
adr_stats = df.groupby('hotel')['adr'].describe()
print(adr_stats)
# Out:
#                 count        mean        std   min      25%    50%    75%  \
# hotel
# City Hotel    53428.0  110.985944  48.062518  0.00  84.0000  105.3  134.0
# Resort Hotel  33968.0   99.025346  63.766782 -6.38  51.3925   79.5  134.0
#
#                  max
# hotel
# City Hotel    5400.0
# Resort Hotel   508.0

# %% [markdown]
# **Distribution of cancellations over week numbers**

# %%
df1['length_of_stay'] = df1['stays_in_weekend_nights'] + df1['stays_in_week_nights']
#print(df[['stays_in_weekend_nights', 'stays_in_week_nights', 'length_of_stay']].head())

#Calculating the average ADR for each length of stay
adr_by_length_of_stay = df1.groupby('length_of_stay')['adr'].mean().reset_index(name='avg adr')

print(adr_by_length_of_stay)




non_zero_df = adr_by_length_of_stay[adr_by_length_of_stay['avg adr'] > 0]

optimal_length_of_stay = adr_by_length_of_stay.loc[non_zero_df['avg adr'].idxmin()]
print(f"The optimal length of stay is {optimal_length_of_stay['length_of_stay']} nights.")


plt.figure(figsize=(12, 6))
sns.lineplot(data=adr_by_length_of_stay, x='length_of_stay', y='avg adr', marker='o', color='blue')
plt.axvline(optimal_length_of_stay['length_of_stay'], color='red', linestyle='--', label=f'Optimal Length of Stay: {optimal_length_of_stay["length_of_stay"]} nights')
plt.xlabel('Length of Stay (nights)')
plt.ylabel('Average Daily Rate (ADR)')
plt.title('Average Daily Rate (ADR) by Length of Stay')
plt.legend()
plt.show()
# Out:
#     length_of_stay     avg adr
# 0                0    0.000000
# 1                1   96.332516
# 2                2  106.266102
# 3                3  110.883634
# 4                4  109.216113
# 5                5  114.612864
# 6                6  122.295426
# 7                7  107.438658
# 8                8  116.667816
# 9                9  116.261833
# 10              10  109.177388
# 11              11  109.534595
# 12              12  108.072211
# 13              13  115.140970
# 14              14   95.657622
# 15              15   92.015694
# 16              16  104.263333
# 17              17   95.355000
# 18              18   86.905417
# 19              19   99.495455
# 20              20   76.225000
# 21              21   77.308545
# 22              22   77.250769
# 23              23   75.620000
# 24              24   83.590000
# 25              25   60.422143
# 26              26   73.790000
# 27              27   63.760000
# 28              28   58.114286
# ...

# %% [markdown]
# ### **Does the guest get the rooms which they reserved?**

# %%
df['room_type_match']=df['reserved_room_type']==df['assigned_room_type']

# Counting the number of matches and mismatches
match_counts = df['room_type_match'].value_counts()
print(match_counts)

# Group by hotel type and calculate the match rate
match_rate_by_hotel = df.groupby('hotel')['room_type_match'].mean().reset_index()
match_rate_by_hotel.columns = ['Hotel', 'Match_Rate']

# Printing the match rate for each hotel type
print(match_rate_by_hotel)
# Out:
# room_type_match
# True     74287
# False    13109
# Name: count, dtype: int64
#           Hotel  Match_Rate
# 0    City Hotel    0.885977
# 1  Resort Hotel    0.793423

# %% [markdown]
# CONCLUSION: The "**City hotel**" is better at assigning guests the room type they reserved.

# %% [markdown]
# ### **which country is hosting more number of guests ?**

# %%
df1[['children']] = df1[['children']].astype('int64')

df1['guests_count']=df1['adults']+df1['children']+df1['babies']

country_df = df1.groupby('country')['guests_count'].size().reset_index()
#print(country_df)

max_guest_count = country_df.loc[country_df['guests_count'].idxmax()]
print(max_guest_count)
# Out:
# country           PRT
# guests_count    27453
# Name: 136, dtype: object

# %% [markdown]
# We can conclude that Portugal have highest number of guests with the count of 27453

# %% [markdown]
# **Which room type is most preffered by guests?**

# %%
Prefered_Room_Type=df1['reserved_room_type'].value_counts().reset_index(name='count')
print(Prefered_Room_Type)

plt.figure(figsize=(20,15))
sns.barplot(x=Prefered_Room_Type['reserved_room_type'], y=Prefered_Room_Type['count'])
plt.title('Number of guests from each country', fontsize=20)
plt.show()
# Out:
#   reserved_room_type  count
# 0                  A  56552
# 1                  D  17398
# 2                  E   6049
# 3                  F   2823
# 4                  G   2052
# 5                  B    999
# 6                  C    915
# 7                  H    596
# 8                  L      6
# 9                  P      6

# %% [markdown]
# CONCLUSION: '**A**' room type is most preffered by guests.

# %% [markdown]
# ### **Which types of customers mostly make bookings?**

# %%
cust_type = df1['customer_type'].value_counts().reset_index(name='customer_type_count')
print(cust_type)
plt.title("Types of customers mostly make bookings", color = 'teal', weight = 'bold', fontsize = 15 )
plt.bar(cust_type['customer_type'], cust_type['customer_type_count'], color='black')
plt.xlabel("Types of customers", color = 'teal', weight = 'bold', fontsize = 10)
plt.ylabel("Number of counts", color = 'teal', weight = 'bold', fontsize = 10)
plt.show()
# Out:
#      customer_type  customer_type_count
# 0        Transient                71986
# 1  Transient-Party                11727
# 2         Contract                 3139
# 3            Group                  544

# %% [markdown]
# CONCLUSION: The **Transient-Party** types of customers mostly make bookings

# %% [markdown]
# ## **Distribution of Bookings by Distribution Channel**

# %%
# Creating a datset of distribution channel name and count
dist_df = df1['distribution_channel'].value_counts().reset_index(name='channel count')
print(dist_df)

plt.figure(figsize=(6, 6))  # Adjusting the figure size as needed
patches, texts, autotexts = plt.pie(dist_df['channel count'], autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

# Adding a legend to the chart
plt.legend(patches, dist_df['distribution_channel'], loc="best")

# Adding a title
plt.title('Distribution of Bookings by Distribution Channel')

# Ensuring that pie is drawn as a circle
plt.axis('equal')

# Displaying the chart
plt.show()
# Out:
#   distribution_channel  channel count
# 0                TA/TO          69141
# 1               Direct          12988
# 2            Corporate           5081
# 3                  GDS            181
# 4            Undefined              5
